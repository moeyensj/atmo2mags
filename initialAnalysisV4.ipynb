# %% [markdown]
# ## Initial Analysis - Constraints on Atmospheric Transmissivity from Stellar Photometry - February 2015
#
# This ipython notebook will run through the initial analysis described in section 2.2 of the research paper titled above. Note: This notebook contains LSST stack dependencies and several script imports; this notebook uses the atmoBuilder class contrary to the original initialAnalysis notebook. Furthermore, this notebook will focus on integrating principles from AstroML:  Chapter 8 on linear and nonlinear regressions with log-likelihood functions.
#
# Global variables in Sed.py, Bandpass.py must be set to following in order to match MODTRAN data:
#
# - MINWAVELEN = 300
# - MAXWAVELEN = 1100
# - WAVELENSTEP = 0.5
#
# Requires the following to be sourced / setup with eups:
# - setup sims_photUtils -t sims
# - setup sims_sed_library -t sims

# %%
import numpy 
import matplotlib.pyplot as plt
import pylab
from astroML.plotting.mcmc import convert_to_stdev
from astroML.decorators import pickle_results

from AtmoBuilder import AtmoBuilder

% matplotlib inline

# %%
ab = AtmoBuilder()
# Out:
# Found 16 MODTRAN files:
# Pachon_MODTRAN.10.7sc
# Pachon_MODTRAN.11.7sc
# Pachon_MODTRAN.12.7sc
# Pachon_MODTRAN.13.7sc
# Pachon_MODTRAN.14.7sc
# Pachon_MODTRAN.15.7sc
# Pachon_MODTRAN.16.7sc
# Pachon_MODTRAN.17.7sc
# Pachon_MODTRAN.18.7sc
# Pachon_MODTRAN.19.7sc
# Pachon_MODTRAN.20.7sc
# Pachon_MODTRAN.21.7sc
# Pachon_MODTRAN.22.7sc
# Pachon_MODTRAN.23.7sc
# Pachon_MODTRAN.24.7sc
# Pachon_MODTRAN.25.7sc
# MODTRAN files have been read.

# %%
# Required for dmags
ab.readKurucz()
# Out:
# # Read 988 MS stars from /Users/joachim/lsst/DarwinX86/sims_sed_library/2014.10.06/starSED/kurucz/

# %% [markdown]
# ###Number of bins set to 25 for all function calls below to decrease computation time. Will run 100 bin computations soon.

# %%
range_Rayleigh, range_Aerosol, best_Rayleigh, best_Aerosol, logL = ab.compute_mag_color_nonlinear('Rayleigh','Aerosol',P=[1.0,1.0,1.0,2.3,0.8,1.7],Nbins=25)
# Out:
# Computing nonlinear regression for Rayleigh and Aerosol.
# Atmosphere Parameters = [1.0, 1.0, 1.0, 2.3, 0.8, 1.7]
# @pickle_results: using precomputed results from 'X14_P101010230817_Rayleigh_Aerosol_25bins.pkl'
# u 2.29166666667 0.833333333333
# g 2.29166666667 0.833333333333
# r 1.25 2.08333333333
# i 2.29166666667 0.833333333333
# z 2.29166666667 0.833333333333
# y4 2.29166666667 0.833333333333

# %%
range_Rayleigh, range_Aerosol, best_Rayleigh, best_Aerosol, logL = ab.compute_mag_color_nonlinear('Rayleigh','Aerosol',P=[1.0,1.0,1.0,0.6,3.2,1.7],Nbins=25)
# Out:
# Computing nonlinear regression for Rayleigh and Aerosol.
# Atmosphere Parameters = [1.0, 1.0, 1.0, 0.6, 3.2, 1.7]
# @pickle_results: using precomputed results from 'X14_P101010063217_Rayleigh_Aerosol_25bins.pkl'
# u 0.416666666667 4.375
# g 0.625 3.125
# r 0.833333333333 2.91666666667
# i 0.416666666667 3.33333333333
# z 0.625 3.125
# y4 0.625 3.125

# %%
range_Aerosol, range_Alpha, best_Aerosol, best_Alpha, logL = ab.compute_mag_color_nonlinear('Aerosol','Alpha',P=[1.0,1.0,1.0,1.0,0.2,2.9],Nbins=25)
# Out:
# Computing nonlinear regression for Aerosol and Alpha.
# Atmosphere Parameters = [1.0, 1.0, 1.0, 1.0, 0.2, 2.9]
# @pickle_results: using precomputed results from 'X14_P101010100229_Aerosol_Alpha_25bins.pkl'
# u 2.70833333333 0.208333333333
# g 0.208333333333 2.70833333333
# r 0.208333333333 2.70833333333
# i 0.208333333333 2.70833333333
# z 2.70833333333 0.208333333333
# y4 0.208333333333 2.70833333333

# %%
range_Aerosol, range_Alpha, best_Aerosol, best_Alpha, logL = ab.compute_mag_color_nonlinear('Aerosol','Alpha',P=[1.0,1.0,1.0,1.0,2.5,0.9],Nbins=25)
# Out:
# Computing nonlinear regression for Aerosol and Alpha.
# Atmosphere Parameters = [1.0, 1.0, 1.0, 1.0, 2.5, 0.9]
# @pickle_results: using precomputed results from 'X14_P101010102509_Aerosol_Alpha_25bins.pkl'
# u 2.70833333333 0.833333333333
# g 2.70833333333 0.833333333333
# r 0.833333333333 2.70833333333
# i 2.70833333333 0.833333333333
# z 0.833333333333 2.70833333333
# y4 0.833333333333 2.70833333333

# %%
# 03,02 out of curiosity
range_O2, range_O3, best_O2, best_O3, logL = ab.compute_mag_color_nonlinear('O2','O3',P=[1.0,0.3,2.2,1.0,1.0,1.7],Nbins=25)
# Out:
# Computing nonlinear regression for O2 and O3.
# Atmosphere Parameters = [1.0, 0.3, 2.2, 1.0, 1.0, 1.7]
# @pickle_results: using precomputed results from 'X14_P100322101017_O2_O3_25bins.pkl'
# u 5.0 2.29166666667
# g 0.0 2.29166666667
# r 0.0 2.08333333333
# i 0.208333333333 2.08333333333
# z 3.95833333333 2.08333333333
# y4 0.416666666667 2.29166666667

# %%
range_H2O, range_O3, best_H2O, best_O3, logL = ab.compute_mag_color_nonlinear('H2O','O3',P=[2.6,1.0,1.7,1.0,1.0,1.7],Nbins=25)
# Out:
# Computing nonlinear regression for H2O and O3.
# Atmosphere Parameters = [2.6, 1.0, 1.7, 1.0, 1.0, 1.7]
# @pickle_results: using precomputed results from 'X14_P261017101017_H2O_O3_25bins.pkl'
# u 0.0 1.66666666667
# g 5.0 1.66666666667
# r 1.66666666667 1.66666666667
# i 2.70833333333 1.66666666667
# z 2.5 1.04166666667
# y4 2.5 5.0

# %% [markdown]
# ### 100 bin computation

# %%
range_Aerosol, range_Alpha, best_Aerosol, best_Alpha, logL = ab.compute_mag_color_nonlinear('Aerosol','Alpha',P=[1.0,1.0,1.0,1.0,0.2,2.9],Nbins=100)
# Out:
# Computing nonlinear regression for Aerosol and Alpha.
# Atmosphere Parameters = [1.0, 1.0, 1.0, 1.0, 0.2, 2.9]
# @pickle_results: using precomputed results from 'X14_P101010100229_Aerosol_Alpha_100bins.pkl'
# u 1.91919191919 0.30303030303
# g 3.83838383838 0.151515151515
# r 3.83838383838 0.151515151515
# i 0.151515151515 3.83838383838
# z 0.20202020202 2.87878787879
# y4 1.91919191919 0.30303030303

# %%
range_Rayleigh, range_Alpha, best_Rayleigh, best_Alpha, logL = ab.compute_mag_color_nonlinear('Rayleigh','Alpha',P=[1.0,1.0,1.0,0.2,1.0,2.9],Nbins=100)
# Out:
# Computing nonlinear regression for Rayleigh and Alpha.
# Atmosphere Parameters = [1.0, 1.0, 1.0, 0.2, 1.0, 2.9]
# @pickle_results: using precomputed results from 'X14_P101010021029_Rayleigh_Alpha_100bins.pkl'
# u 0.20202020202 2.87878787879
# g 0.10101010101 3.38383838384
# r 0.353535353535 2.57575757576
# i 0.252525252525 2.82828282828
# z 0.20202020202 2.87878787879
# y4 0.20202020202 2.87878787879
