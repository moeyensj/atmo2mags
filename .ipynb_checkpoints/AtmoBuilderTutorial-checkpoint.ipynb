# %% [markdown]
# ## AtmoBuilder.py Tutorial

# %% [markdown]
# #### Installation:

# %% [markdown]
# #### Importing and initializing:

# %%
from AtmoBuilder import AtmoBuilder

# shows plots within notebook cells
% matplotlib inline

# %%
# Initialize the class
# By default it will look in the current directory for a 'modtran/' folder containing the relevant MODTRAN files 
# and read them in. It will also read in LSST filter and hardware data from the LSST stack
ab = AtmoBuilder()
# Out:
# Found 16 MODTRAN files:
# Pachon_MODTRAN.10.7sc
# Pachon_MODTRAN.11.7sc
# Pachon_MODTRAN.12.7sc
# Pachon_MODTRAN.13.7sc
# Pachon_MODTRAN.14.7sc
# Pachon_MODTRAN.15.7sc
# Pachon_MODTRAN.16.7sc
# Pachon_MODTRAN.17.7sc
# Pachon_MODTRAN.18.7sc
# Pachon_MODTRAN.19.7sc
# Pachon_MODTRAN.20.7sc
# Pachon_MODTRAN.21.7sc
# Pachon_MODTRAN.22.7sc
# Pachon_MODTRAN.23.7sc
# Pachon_MODTRAN.24.7sc
# Pachon_MODTRAN.25.7sc
# MODTRAN files have been read.

# %% [markdown]
# #### Basic functions:

# %%
ab.filterPlot()

# %%
ab.hardwarePlot()

# %%
ab.airmass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-aefb5e4b49e6> in <module>()
# ----> 1 ab.airmass
#
# AttributeError: AtmoBuilder instance has no attribute 'airmass'
