# %%
from AtmoBuilder import AtmoBuilder

% matplotlib inline

# %%
ab = AtmoBuilder()
# Out:
# Found 16 MODTRAN files:
# Pachon_MODTRAN.10.7sc
# Pachon_MODTRAN.11.7sc
# Pachon_MODTRAN.12.7sc
# Pachon_MODTRAN.13.7sc
# Pachon_MODTRAN.14.7sc
# Pachon_MODTRAN.15.7sc
# Pachon_MODTRAN.16.7sc
# Pachon_MODTRAN.17.7sc
# Pachon_MODTRAN.18.7sc
# Pachon_MODTRAN.19.7sc
# Pachon_MODTRAN.20.7sc
# Pachon_MODTRAN.21.7sc
# Pachon_MODTRAN.22.7sc
# Pachon_MODTRAN.23.7sc
# Pachon_MODTRAN.24.7sc
# Pachon_MODTRAN.25.7sc
# MODTRAN files have been read.
#
# Read filter data from LSST software stack.
# Filters: ['u', 'g', 'r', 'i', 'z', 'y4']
# Read hardware data from LSST software stack.

# %%
atmo_obs= ab.buildAtmo([1.0,1.2,1.0,2.1,1.0,1.7],1.4)

# %%
ab.transPlot(atmo_obs, includeStdAtmo=True)

# %%
tp_obs = ab.combineThroughputs(atmo_obs)

# %%
ab.throughputPlot(tp_obs)

# %%
ab.readAll()
# Out:
# # Read 988 MS stars from /Users/joachim/lsst/lsst/DarwinX86/sims_sed_library/2014.10.06/starSED/kurucz/
# # Read 849 white dwarfs from /Users/joachim/lsst/lsst/DarwinX86/sims_sed_library/2014.10.06/starSED/wDs/
# # Read 74 mlt stars from /Users/joachim/lsst/lsst/DarwinX86/sims_sed_library/2014.10.06/starSED/mlt/
# # Generated 2520 galaxies at redshifts between 0.000000 and 3.000000
# # Generated 76 quasars at redshifts between 0.000000 and 7.500000
# # Generated 39 sn's at redshifts between 0.000000 and 1.200000 on days ['0', '20', '40']

# %%
mags = ab.mags(tp_obs)

# %%
print mags['u']
# Out:
# [-17.4587472  -17.45988211 -17.46094502 -17.46194378 -17.46308775
#  -17.46394095 -17.46494325 -17.46170414 -17.45778656 -17.45390073
#  -17.45000054 -17.44617243 -17.44251026 -17.43885545 -17.43524599
#  -17.43150362 -17.42797561 -17.42424041 -17.42072105 -17.41889137
#  -17.41891482 -17.41875637 -17.41857911 -17.41851834 -17.41824142
#  -17.41827957 -17.41808995 -17.41791642 -17.41793659 -17.41776283
#  -17.41764399 -17.41752621 -17.4176095  -17.41767489 -17.41776748
#  -17.41794856 -17.41808453 -17.41836498 -17.41845235 -17.41853324
#  -17.41871521 -17.41887477 -17.4189991  -17.41911337 -17.41932771
#  -17.41945494 -17.46856841 -17.46940923 -17.47019698 -17.47114737
#  -17.47173905 -17.45656822 -17.45256218 -17.44888085 -17.44485362
#  -17.44121492 -17.43744662 -17.43371157 -17.42997137 -17.42817739
#  -17.42798924 -17.42762616 -17.42736495 -17.42687987 -17.42657432
#  -17.42640915 -17.42598031 -17.42572551 -17.42557577 -17.42527446
# ...

# %%
ab.dmagPlot(tp_obs,tp_obs,'qsos')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-3d7f269d77de> in <module>()
# ----> 1 ab.dmagPlot(tp_obs,tp_obs,'qsos')
#
# /Users/joachim/atmo2mags/AtmoBuilder.pyc in dmagPlot(self, bpDict1, bpDict_std, sedtype, bpDict2, filters, deltaGrey, dmagLimit, figName)
#    2494         for i in range(rows):
#    2495             for j in range(columns):
# -> 2496                 dmags = self._dmagSED(ax[i][j], filters[i][j], bpDict1, bpDict_std, sedtype, bpDict2=bpDict2, truth=True, dmagLimit=dmagLimit, deltaGrey1=deltaGrey)
#    2497                 if dmagLimit:
#    2498                     self._axisLimiter(ax[i][j],[-2.0,2.0])
#
# /Users/joachim/atmo2mags/AtmoBuilder.pyc in _dmagSED(self, ax, f, bpDict1, bpDict_std, sedtype, bpDict2, deltaGrey1, deltaGrey2, truth, comparisonSed, dmagLimit, colorRange)
# ...
